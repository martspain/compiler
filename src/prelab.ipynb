# %% [markdown]
# # Prelab

# %%
from lex import AFN_from_RegEx
from utils import infixToPostfix

# %% [markdown]
# ## 1. ```ab*ab*```

# %%
regexTest = 'ab*ab*'

postfix = infixToPostfix(regexTest)
postfix
# Out:
# 'ab*.a.b*.'

# %%
AFN_from_RegEx(postfix)

# %% [markdown]
# ## 2. ```0?(1?)?0*```

# %%
regexTest = '0?(1?)?0*'

postfix = infixToPostfix(regexTest)
postfix
# Out:
# '0?1??.0*.'

# %%
AFN_from_RegEx(postfix)

# %% [markdown]
# ## 3. ```(a*|b*)c```

# %%
regexTest = '(a*|b*)c'

postfix = infixToPostfix(regexTest)
postfix
# Out:
# 'a*b*|c.'

# %%
AFN_from_RegEx(postfix)

# %% [markdown]
# ## 4. ```(b|b)*abb(a|b)*```

# %%
regexTest = '(b|b)*abb(a|b)*'

postfix = infixToPostfix(regexTest)
postfix
# Out:
# 'bb|*a.b.b.ab|*.'

# %%
AFN_from_RegEx(postfix)

# %% [markdown]
# ## 5. ```(a|ε)b(a+)c?```

# %%
regexTest = '(a|ε)b(a+)c?'

postfix = infixToPostfix(regexTest)
postfix
# Out:
# 'aε|b.a+.c?.'

# %%
AFN_from_RegEx(postfix)

# %% [markdown]
# ## 6. ```(a|b)*a(a|b)(a|b)```

# %%
regexTest = '(a|b)*a(a|b)(a|b)'

postfix = infixToPostfix(regexTest)
postfix
# Out:
# 'ab|*a.ab|.ab|.'

# %%
AFN_from_RegEx(postfix)
